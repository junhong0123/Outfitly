# %% [markdown]
# # Data Exploration for Outfitly AI Engine
#
# Welcome to the data exploration notebook. This notebook is intended to load your e-commerce data (from CSV or direct DB connection) and perform basic exploratory data analysis (EDA).
#
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
plt.style.use('ggplot')

# %% [markdown]
# ## 2. Load Data
# *(Uncomment and adapt the cell below to load your dataset)*

# %%
# df = pd.read_csv('data/products.csv')
# df.head()
